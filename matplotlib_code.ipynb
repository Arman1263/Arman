# %% [markdown]
# <a href="https://colab.research.google.com/github/Arman1263/Arman/blob/main/matplotlib_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pylab as plt
import numpy as np

xcor = np.array([0, 44])
ycor = np.array([22, 100])

plt.plot(xcor, ycor)

plt.show()
